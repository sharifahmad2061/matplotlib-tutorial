# %% [markdown]
# # import stuff

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # load data

# %%
df = pd.read_csv('titanic-dataset.csv')

# %% [markdown]
# # sin curve

# %%
x = np.linspace(0,2*np.pi,100)
sinx = np.sin(x)

# %%
fig, ax = plt.subplots()
_ = ax.plot(x,sinx)

# %%
fig, ax = plt.subplots(figsize=(15,10))
_ = ax.plot(x,sinx,marker='*',linestyle='')
_ = ax.set_aspect('equal') # sets aspect ration

# %% [markdown]
# # change color
# color : changes the color of the prominent object in the plot. eg in line graph, line is the prominent object.

# %%
fig, ax = plt.subplots(figsize=(15,10))
_ = ax.plot(x,sinx,marker='.',linestyle='',markeredgecolor='green',
           markerfacecolor='white',markersize=20)
_ = ax.set_aspect('equal') # sets aspect ration

# %% [markdown]
# ## Legend

# %%
fig, ax = plt.subplots(figsize=(15,10))
_ = ax.plot(x,sinx,marker='.',markeredgecolor='green',
           markerfacecolor='white',markersize=20,label='sin')
_ = ax.set_aspect('equal') # sets aspect ration
_ = ax.legend() # we can also use 0,1,2 etc and human readable
# forms like upper right, lower right etc.
